# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import seaborn

from data import DATA_ROOT_DIRECTORY_PATH
from os.path import join


from matplotlib import pyplot
import matplotlib.pyplot as plt
import matplotlib
from plot import bar_plot_top_n

from collections import defaultdict
from preprocessing import create_datasets_for_two_version, text_preprocessing, get_n_most_popular_words
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
create_datasets_for_two_version()
# Out:
# 625 issued for version 2020.2 found.
# 522 issued for version 2020.3 found.

# %%
words2, cts2 = get_n_most_popular_words("2020.2")
words3, cts3 = get_n_most_popular_words("2020.3")
# Out:
# Total word count in dataset: 3969.
# Total word count in dataset: 3416.

# %%
bar_plot_top_n([words2, cts2], "2020.2")

# %%
bar_plot_top_n([words3, cts3], "2020.3")
